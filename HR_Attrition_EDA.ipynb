# %%
pip install pandas numpy matplotlib seaborn
# Out:
# Requirement already satisfied: pandas in c:\users\adhit\appdata\local\programs\python\python311\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy in c:\users\adhit\appdata\local\programs\python\python311\lib\site-packages (2.1.3)
# Requirement already satisfied: matplotlib in c:\users\adhit\appdata\local\programs\python\python311\lib\site-packages (3.10.3)
# Requirement already satisfied: seaborn in c:\users\adhit\appdata\local\programs\python\python311\lib\site-packages (0.13.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\adhit\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\adhit\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\adhit\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\adhit\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\adhit\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\adhit\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\adhit\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\adhit\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\adhit\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\adhit\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: six>=1.5 in c:\users\adhit\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('HR_Employee_Attrition.csv')
df.head()
# Out:
#    EmployeeID  Age              Department    EducationField  Gender  \
# 0           1   49         Human Resources  Technical Degree    Male
# 1           2   33  Research & Development     Life Sciences  Female
# 2           3   36         Human Resources         Marketing    Male
# 3           4   26         Human Resources           Medical    Male
# 4           5   22                   Sales           Medical    Male
#
#                      JobRole  MonthlyIncome  YearsAtCompany Attrition  \
# 0            Sales Executive          16125               2        No
# 1  Healthcare Representative           5705              12        No
# 2            Sales Executive          19114              27       Yes
# 3                    Manager           5901              29        No
# 4     Manufacturing Director          14470              27        No
#
#   MaritalStatus  JobSatisfaction  EnvironmentSatisfaction  WorkLifeBalance
# 0      Divorced                2                        2                4
# 1        Single                1                        1                4
# 2       Married                1                        4                3
# 3       Married                3                        3                2
# 4       Married                2                        2                3

# %%
print(df.shape)
print(df.info())
print(df.describe())
print(df['Attrition'].value_counts())
# Out:
# (200, 13)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   EmployeeID               200 non-null    int64
#  1   Age                      200 non-null    int64
#  2   Department               200 non-null    object
#  3   EducationField           200 non-null    object
#  4   Gender                   200 non-null    object
#  5   JobRole                  200 non-null    object
#  6   MonthlyIncome            200 non-null    int64
#  7   YearsAtCompany           200 non-null    int64
#  8   Attrition                200 non-null    object
#  9   MaritalStatus            200 non-null    object
#  10  JobSatisfaction          200 non-null    int64
#  11  EnvironmentSatisfaction  200 non-null    int64
#  12  WorkLifeBalance          200 non-null    int64
# dtypes: int64(7), object(6)
# memory usage: 20.4+ KB
# None
#        EmployeeID         Age  MonthlyIncome  YearsAtCompany  JobSatisfaction  \
# count  200.000000  200.000000      200.00000      200.000000       200.000000
# mean   100.500000   40.010000    10685.10000       20.050000         2.550000
# std     57.879185   12.285952     5281.68918       12.214066         1.159405
# min      1.000000   18.000000     2079.00000        0.000000         1.000000
# 25%     50.750000   29.750000     6144.00000        9.750000         1.000000
# 50%    100.500000   41.000000    10500.50000       18.500000         3.000000
# 75%    150.250000   50.000000    15302.75000       31.000000         4.000000
# max    200.000000   60.000000    19951.00000       40.000000         4.000000
#
#        EnvironmentSatisfaction  WorkLifeBalance
# count               200.000000       200.000000
# mean                  2.390000         2.475000
# std                   1.088035         1.111554
# min                   1.000000         1.000000
# 25%                   1.000000         2.000000
# 50%                   2.000000         2.000000
# 75%                   3.000000         3.250000
# max                   4.000000         4.000000
# Attrition
# No     101
# Yes     99
# Name: count, dtype: int64

# %%
df.isnull().sum()  # Check for nulls
df.duplicated().sum()  # Check for duplicates
# Out:
# np.int64(0)

# %%
sns.countplot(x='Attrition', data=df)
plt.title("Attrition Count")
plt.show()

sns.histplot(df['Age'], bins=20)
plt.title("Age Distribution")
plt.show()

# %%
sns.boxplot(x='Attrition', y='MonthlyIncome', data=df)
plt.title("Monthly Income vs Attrition")
plt.show()

sns.countplot(x='JobRole', hue='Attrition', data=df)
plt.xticks(rotation=45)
plt.title("Job Role vs Attrition")
plt.show()

# %%
# Select only numeric columns
numeric_df = df.select_dtypes(include=['float64', 'int64'])

# Plot heatmap for correlation
plt.figure(figsize=(12, 8))
sns.heatmap(numeric_df.corr(), annot=True, fmt=".2f", cmap='coolwarm')
plt.title("Correlation Matrix (Numeric Features Only)")
plt.show()
